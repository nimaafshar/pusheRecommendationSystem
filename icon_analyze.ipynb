# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('icons.csv')

# %%
data.set_index('notif_id',inplace=True)

# %%
# different icons
len(data.drop_duplicates())
# Out:
# 2726

# %%
l = [f'F{i}'for i in range(1,201)]
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
l
# Out:
# ['F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'F6',
#  'F7',
#  'F8',
#  'F9',
#  'F10',
#  'F11',
#  'F12',
#  'F13',
#  'F14',
#  'F15',
#  'F16',
#  'F17',
#  'F18',
#  'F19',
#  'F20',
#  'F21',
#  'F22',
#  'F23',
#  'F24',
#  'F25',
#  'F26',
#  'F27',
#  'F28',
#  'F29',
#  'F30',
#  'F31',
#  'F32',
#  'F33',
#  'F34',
#  'F35',
#  'F36',
#  'F37',
#  'F38',
#  'F39',
#  'F40',
#  'F41',
#  'F42',
#  'F43',
#  'F44',
#  'F45',
#  'F46',
#  'F47',
#  'F48',
#  'F49',
#  'F50',
#  'F51',
#  'F52',
#  'F53',
#  'F54',
#  'F55',
#  'F56',
#  'F57',
#  'F58',
#  'F59',
#  'F60',
#  'F61',
#  'F62',
#  'F63',
#  'F64',
#  'F65',
#  'F66',
#  'F67',
#  'F68',
#  'F69',
#  'F70',
#  'F71',
#  'F72',
#  'F73',
#  'F74',
#  'F75',
#  'F76',
#  'F77',
#  'F78',
#  'F79',
#  'F80',
#  'F81',
#  'F82',
#  'F83',
#  'F84',
#  'F85',
#  'F86',
#  'F87',
#  'F88',
#  'F89',
#  'F90',
#  'F91',
#  'F92',
#  'F93',
#  'F94',
#  'F95',
#  'F96',
#  'F97',
#  'F98',
#  'F99',
#  'F100',
# ...

# %%
df = data.reset_index().groupby(l).count()

# %%
icon_dist = pd.DataFrame(df).reset_index().notif_id

# %%
plt.plot(sorted(list(icon_dist)))

# %%
data
# Out:
#                  F1         F2         F3         F4         F5         F6  \
# notif_id
# 447519    -4.966424  11.489478   4.418155  -8.264528   0.483450  -8.726120
# 441851     1.695928  -9.561707  -1.148592  -7.545650  -8.476706   5.449286
# 483576    -3.164493   4.960090  -3.474825  -2.931745   1.532727  -2.396772
# 564340    17.057026  -1.445091 -15.867423   2.147889  -7.040503   1.373868
# 549636   -10.604857   4.211807  -3.017962  -3.874277  -4.608191  -5.410021
# 540329     4.359991  -2.307953   7.465089  -8.609141   5.886210   0.279800
# 556098   -11.614460  -8.288644  -3.974762   2.603128   4.582309   6.074615
# 568662    -5.718139   5.476315   6.125578  -4.301112  -1.135807  -2.326439
# 423967     0.735793  -8.365220   6.038379   1.911473 -11.972851  -3.390166
# 561583    -5.602179 -14.642133  -7.394053  -2.442558  -9.416978  -0.504784
# 445347    17.057026  -1.445091 -15.867423   2.147887  -7.040507   1.373858
# ...
